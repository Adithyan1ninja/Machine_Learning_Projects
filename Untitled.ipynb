# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot 
#import seaborn as sns

# %%
df=pd.read_csv("archive/sp500_companies.csv")
df.head()
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 3      NMS   AMZN       Amazon.com, Inc.       Amazon.com, Inc.
# 4      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        254.49
# 1              Technology                  Semiconductors        134.70
# 2              Technology       Software - Infrastructure        436.60
# 3       Consumer Cyclical                 Internet Retail        224.92
# 4  Communication Services  Internet Content & Information        191.41
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3846819807232  1.346610e+11          0.061      Cupertino    CA
# 1  3298803056640  6.118400e+10          1.224    Santa Clara    CA
# 2  3246068596736  1.365520e+11          0.160        Redmond    WA
# 3  2365033807872  1.115830e+11          0.110        Seattle    WA
# 4  2351625142272  1.234700e+11          0.151  Mountain View    CA
#
#          Country  Fulltimeemployees  \
# 0  United States           164000.0
# 1  United States            29600.0
# 2  United States           228000.0
# 3  United States          1551000.0
# 4  United States           181269.0
#
#                                  Longbusinesssummary    Weight
# 0  Apple Inc. designs, manufactures, and markets ...  0.069209
# 1  NVIDIA Corporation provides graphics and compu...  0.059350
# 2  Microsoft Corporation develops and supports so...  0.058401
# 3  Amazon.com, Inc. engages in the retail sale of...  0.042550
# 4  Alphabet Inc. offers various products and plat...  0.042309

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exchange             502 non-null    object
#  1   Symbol               502 non-null    object
#  2   Shortname            502 non-null    object
#  3   Longname             502 non-null    object
#  4   Sector               502 non-null    object
#  5   Industry             502 non-null    object
#  6   Currentprice         502 non-null    float64
#  7   Marketcap            502 non-null    int64
#  8   Ebitda               473 non-null    float64
#  9   Revenuegrowth        499 non-null    float64
#  10  City                 502 non-null    object
#  11  State                482 non-null    object
#  12  Country              502 non-null    object
#  13  Fulltimeemployees    493 non-null    float64
#  14  Longbusinesssummary  502 non-null    object
#  15  Weight               502 non-null    float64
# dtypes: float64(5), int64(1), object(10)
# memory usage: 62.9+ KB

# %%
df.describe()
# Out:
#        Currentprice     Marketcap        Ebitda  Revenuegrowth  \
# count    502.000000  5.020000e+02  4.730000e+02     499.000000
# mean     217.893685  1.107222e+11  7.045286e+09       0.070541
# std      489.205027  3.440074e+11  1.624213e+10       0.180247
# min        9.400000  4.664099e+09 -3.991000e+09      -0.602000
# 25%       68.547500  1.933417e+10  1.625000e+09       0.002000
# 50%      118.365000  3.706396e+10  2.952748e+09       0.051000
# 75%      227.667500  7.830565e+10  6.020000e+09       0.109000
# max     8276.780000  3.846820e+12  1.495470e+11       1.632000
#
#        Fulltimeemployees      Weight
# count       4.930000e+02  502.000000
# mean        5.782761e+04    0.001992
# std         1.395988e+05    0.006189
# min         2.800000e+01    0.000084
# 25%         1.020000e+04    0.000348
# 50%         2.169000e+04    0.000667
# 75%         5.510000e+04    0.001409
# max         2.100000e+06    0.069209

# %%
df.isnull().sum()
# Out:
# Exchange                0
# Symbol                  0
# Shortname               0
# Longname                0
# Sector                  0
# Industry                0
# Currentprice            0
# Marketcap               0
# Ebitda                 29
# Revenuegrowth           3
# City                    0
# State                  20
# Country                 0
# Fulltimeemployees       9
# Longbusinesssummary     0
# Weight                  0
# dtype: int64

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
#plt.figure(f)

plt.figure(figsize=(10,5))
sns.barplot(data=df,x='Sector',y='Marketcap',estimator='sum')
plt.xticks(rotation=90)
plt.title("Total Market Cap by Sector")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x='Sector' ,y='Revenuegrowth')
plt.xticks(rotation=90)
plt.title("Revenue growth")
plt.show()

# %%
df_model=df[['Marketcap', 'Ebitda', 'Revenuegrowth', 'Currentprice', 'Weight']].copy()

# %%
df_model.dropna(inplace=True)

# %%
X,Y=df_model.drop('Marketcap',axis=1),df_model['Marketcap']

# %%
X.describe()
# Out:
#              Ebitda  Revenuegrowth  Currentprice      Weight
# count  4.700000e+02     470.000000    470.000000  470.000000
# mean   6.967853e+09       0.070023    223.152191    0.001996
# std    1.617977e+10       0.179207    503.989584    0.006368
# min   -3.991000e+09      -0.484000      9.400000    0.000084
# 25%    1.623194e+09       0.002000     70.647500    0.000337
# 50%    2.941705e+09       0.049000    118.815000    0.000646
# 75%    6.006000e+09       0.106750    228.235000    0.001385
# max    1.495470e+11       1.632000   8276.780000    0.069209

# %%
X.head()
# Out:
#          Ebitda  Revenuegrowth  Currentprice    Weight
# 0  1.346610e+11          0.061        254.49  0.069209
# 1  6.118400e+10          1.224        134.70  0.059350
# 2  1.365520e+11          0.160        436.60  0.058401
# 3  1.115830e+11          0.110        224.92  0.042550
# 4  1.234700e+11          0.151        191.41  0.042309

# %%
Y.head()
# Out:
# 0    3846819807232
# 1    3298803056640
# 2    3246068596736
# 3    2365033807872
# 4    2351625142272
# Name: Marketcap, dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\texol\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.6.0)

# %%
import sklearn
print(sklearn.__version__)

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
print("imports ok")
# Out:
# 1.6.1
# imports ok

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
model = GradientBoostingRegressor()
model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred=model.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9641000450067722
